# %%
from langchain_core.runnables import Runnable
from typing import Callable

def objective_function(chain: Runnable, metrics: Callable, document_list: list[str]) -> list[int]:
    evaluation = [metrics(summary) for summary in chain.batch(document_list)]
    return evaluation
