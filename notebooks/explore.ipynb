# %%
import os
OPENAI_API_BASE= os.environ.get("OPENAI_API_BASE", "https://api-ai.numerique-interieur.com/v1") 
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %%
from langchain_openai import ChatOpenAI
from langchain.chains.summarize import load_summarize_chain
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import WebBaseLoader
from langchain.prompts import PromptTemplate

llm = ChatOpenAI(api_key=OPENAI_API_KEY, openai_api_base=OPENAI_API_BASE, temperature=0)
# Out:
# /home/jerome/miniforge3/envs/dev/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x7f66d9d47410>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7f66dbfdff50>, temperature=0.0, openai_api_key='sk-Z_rheVjtag_nTqVKq2dQDA', openai_api_base='https://api-ai.numerique-interieur.com/v1', openai_proxy='')

# %%
llm.invoke(
    "Why 42 ?"
)
# Out:
# AIMessage(content='\nThe number 42 is often cited as a response to the ultimate question of life, the universe, and everything in Douglas Adams\' science fiction series "The Hitchhiker\'s Guide to the Galaxy." In the story, a supercomputer named Deep Thought is tasked with finding the answer to this question. After seven and a half million years of calculation, Deep Thought reveals that the answer is 42.\n\nHowever, it\'s important to note that this is just a humorous and fictional response. In reality, there is no known mathematical or scientific basis for why 42 might be the answer to life, the universe, and everything. It is simply a clever and memorable joke from Adams\' story.', response_metadata={'token_usage': {'completion_tokens': 160, 'prompt_tokens': 46, 'total_tokens': 206}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-b5e64627-98d6-4afc-a35e-c7b38f5d45f7-0')
